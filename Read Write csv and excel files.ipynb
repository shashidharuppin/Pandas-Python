# %%
import pandas as pd

# %% [markdown]
# # Reading CSV File

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train2.csv")

# %%
df #Data fram have the additional header or rows above the actual column name
# Out:
#     Passenger List Unnamed: 1 Unnamed: 2  \
# 0      PassengerId   Survived     Pclass
# 1                1          0          3
# 2                2          1          1
# 3                3          1          3
# 4                4          1          1
# ..             ...        ...        ...
# 887            887          0          2
# 888            888          1          1
# 889            889          0          3
# 890            890          1          1
# 891            891          0          3
#
#                                             Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                                 Name        Sex        Age
# 1                              Braund, Mr. Owen Harris       male         22
# 2    Cumings, Mrs. John Bradley (Florence Briggs Th...     female         38
# 3                               Heikkinen, Miss. Laina     female         26
# 4         Futrelle, Mrs. Jacques Heath (Lily May Peel)     female         35
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train2.csv", skiprows = 1) # you can remove the unwanted header using skiprows attribute 1 referes to the row which you want to skip
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train2.csv", header = 1) # you can use the header attribute to start the rows from 2. in csv file header = 0 referes to row 1
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train3.csv")
df # you can see that the csv file dont have any header in this case
# Out:
#        1  0  3                            Braund, Mr. Owen Harris    male  \
# 0      2  1  1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 1      3  1  3                             Heikkinen, Miss. Laina  female
# 2      4  1  1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 3      5  0  3                           Allen, Mr. William Henry    male
# 4      6  0  3                                   Moran, Mr. James    male
# ..   ... .. ..                                                ...     ...
# 885  887  0  2                              Montvila, Rev. Juozas    male
# 886  888  1  1                       Graham, Miss. Margaret Edith  female
# 887  889  0  3           Johnston, Miss. Catherine Helen "Carrie"  female
# 888  890  1  1                              Behr, Mr. Karl Howell    male
# 889  891  0  3                                Dooley, Mr. Patrick    male
#
#        22  1.1  0.1         A/5 21171     7.25 Unnamed: 10  S
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train3.csv", header = None)
df # giving header as None will arbitarliy create columns name from 0
# Out:
#       0   1   2                                                  3       4   \
# 0      1   0   3                            Braund, Mr. Owen Harris    male
# 1      2   1   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2      3   1   3                             Heikkinen, Miss. Laina  female
# 3      4   1   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4      5   0   3                           Allen, Mr. William Henry    male
# ..   ...  ..  ..                                                ...     ...
# 886  887   0   2                              Montvila, Rev. Juozas    male
# 887  888   1   1                       Graham, Miss. Margaret Edith  female
# 888  889   0   3           Johnston, Miss. Catherine Helen "Carrie"  female
# 889  890   1   1                              Behr, Mr. Karl Howell    male
# 890  891   0   3                                Dooley, Mr. Patrick    male
#
#        5   6   7                 8        9     10 11
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train3.csv", header = None, names = ["Id","Survived","Pclass","Name","Sex","Age","Sp","Parch","Ticket","Fare","Cabin","Embarked"])
df #this way you can create your own names of the columns whenever there is no headers available
# Out:
#       Id  Survived  Pclass                                               Name  \
# 0      1         0       3                            Braund, Mr. Owen Harris
# 1      2         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2      3         1       3                             Heikkinen, Miss. Laina
# 3      4         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      5         0       3                           Allen, Mr. William Henry
# ..   ...       ...     ...                                                ...
# 886  887         0       2                              Montvila, Rev. Juozas
# 887  888         1       1                       Graham, Miss. Margaret Edith
# 888  889         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889  890         1       1                              Behr, Mr. Karl Howell
# 890  891         0       3                                Dooley, Mr. Patrick
#
# ...

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\train.csv", nrows= 5)
df # you can read the number of rows you wanted from csv file by mentioning nrows = 5 or 10 or 150
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stock_data.csv")
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stock_data.csv", na_values = ["not available","n.a."])
df # It will replace all the not available values with NaN
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
df = pd.read_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stock_data.csv",  na_values={
        'eps': ['not available'],
        'revenue': [-1],
        'people': ['not available','n.a.'],
        'price':['not available','n.a.']
    })
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %% [markdown]
# # Writing to CSV file

# %%
df.to_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\new.csv", index=False) # creating csv file from data frame without index

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\new.csv", index=False,columns =['tickers','eps']) # writing to csv file with only the required column names

# %%
df.to_csv("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\new.csv", index=False,columns =['tickers','eps'], header = False) #writing to csv file without headers

# %% [markdown]
# # Reading Excel file

# %%
df = pd.read_excel("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stock_data.xlsx","stock_data")
df # reading the excel file with the file name and next sheet name
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#Cleaning up the data using the functions for each cell of the df

def convert_people_cell(cell):
    if cell=="n.a.":
        return 'Sam Walton'
    return cell

def convert_price_cell(cell):
    if cell=="n.a.":
        return 50
    return cell
    
def convert_revenue_cell(cell):
    if cell < 0:
        return 0
    return cell

def convert_eps_cell(cell):
    if cell=="not available":
        return None
    return cell

df = pd.read_excel("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stock_data.xlsx","stock_data", converters= {
        'people': convert_people_cell,
        'price': convert_price_cell,
        'revenue':convert_revenue_cell,
        'eps': convert_eps_cell
    })
df
# Out:
#   tickers    eps  revenue  price         people
# 0   GOOGL  27.82       87    845     larry page
# 1     WMT   4.61      484     65     Sam Walton
# 2    MSFT  -1.00       85     64     bill gates
# 3    RIL     NaN       50   1023  mukesh ambani
# 4    TATA   5.60        0     50     ratan tata

# %% [markdown]
# # Writing to excel file

# %%
df.to_excel("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\new.xlsx", sheet_name="stocks", index=False)

# %%
df.to_excel("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\new.xlsx", sheet_name="stocks", index=False, startrow=2, startcol=1)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %% [markdown]
# # Writing 2 different data frames into single excel file

# %%
with pd.ExcelWriter("C:\\Users\\UPPI\\Documents\\Netzwerk\\ML Assign#1\\stocks_weather.xlsx") as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")
